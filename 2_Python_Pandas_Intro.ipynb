# %% [markdown]
# # Getting started with Python and Pandas
#
# Now you've been able to explore what the datasets look like, lets practice using Pandas for analysing data. Kellen's tutorial should have covered the bases so this will just serve as a refresher and reference for you.
#
# Skip to the 'Practice with Real Data' to see Pandas usage with the datasets of this project.
#
#
# TODO remove: Before we do anything else, lets make sure all the Python packages we need throughout this whole project are downloaded and installed. Run the below Jupyter code cell to install the packages we will need. `! pip install <package list>` in Jupyter will run the package installer directly from within the Jupyter notebook

# %%
# TODO remove

# !pip install pandas geopandas geodatasets scipy matplotlib openpyxl seaborn pygeos folium mapclassify
# Out:
# Requirement already satisfied: pandas in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: geopandas in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (0.13.0)
# Requirement already satisfied: geodatasets in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (0.0.0)
# Requirement already satisfied: scipy in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: matplotlib in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: openpyxl in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: seaborn in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: pygeos in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (0.14)
# Requirement already satisfied: folium in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: mapclassify in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: fiona>=1.8.19 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from geopandas) (1.9.4)
# Requirement already satisfied: packaging in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from geopandas) (23.1)
# Requirement already satisfied: pyproj>=3.0.1 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from geopandas) (3.5.0)
# Requirement already satisfied: shapely>=1.7.1 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: pooch in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from geodatasets) (1.7.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: et-xmlfile in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from folium) (3.1.2)
# Requirement already satisfied: branca>=0.6.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from folium) (0.6.0)
# Requirement already satisfied: requests in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from folium) (2.29.0)
# Requirement already satisfied: networkx in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from mapclassify) (3.1)
# Requirement already satisfied: scikit-learn in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: click~=8.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: six in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: certifi in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: cligj>=0.5 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: attrs>=19.2.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: importlib-metadata in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (6.6.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from pooch->geodatasets) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from requests->folium) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from requests->folium) (3.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from scikit-learn->mapclassify) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/76a/Projects/virtualenvs/crosslabtrainingenv/lib/python3.9/site-packages (from scikit-learn->mapclassify) (1.2.0)

# %% [markdown]
# Now that we have the python packages installed, lets start familiarizing ourselves with Pandas - how to view the data, how to visualize the data with charts, how to filter the data and so on.
#
# ### Reading excel files and filtering data with pandas
#
# Importing data from excel into a pandas DataFrame is easy and can be accomplished using the read_excel() function. A pandas DataFrame data structure can be thought of as an excel spreadsheet in python and is laid out similarly with labeled rows and columns of data (the difference being the way it is stored under the hood using multidimensional arrays that allow it to be accessed and used easier in a programmatical fashion). Lets play around with Pandas with an example excel file 2020-movie-data.xlsx.

# %%
# import the pandas package under the alias pd
import pandas as pd

# create a variable to hold the excel file name (optional - can also put the filename directly into the read_excel() function) 
excel_file = 'data/2020-movie-data.xlsx' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object
movie_df = pd.read_excel(excel_file)

# prints the DataFrame to the screen
movie_df
# Out:
#        STUDIO       DATE                   MOVIE     BUDGET  BOX OFFICE
# 0        SONY 2020-01-03              The Grudge   10000000    49400000  \
# 1         FOX 2020-01-10              Underwater   65000000    39200000
# 2   PARAMOUNT 2020-01-10             Like A Boss   29000000    26100000
# 3        SONY 2020-01-17       Bad Boys for Life   90000000   417600000
# 4   UNIVERSAL 2020-01-17                Dolittle  175000000   223300000
# 5   UNIVERSAL 2020-01-24             The Turning   14000000    18500000
# 6   PARAMOUNT 2020-01-31      The Rhythm Section   50000000     5900000
# 7      WARNER 2020-02-07           Birds of Prey   84500000   197900000
# 8         FOX 2020-02-14  Downhill (Searchlight)   15000000     8800000
# 9   PARAMOUNT 2020-02-14      Sonic the Hedgehog   85000000   299600000
# 10       SONY 2020-02-14          Fantasy Island    7000000    45900000
# 11  UNIVERSAL 2020-02-14          The Photograph   16000000    20700000
# 12        FOX 2020-02-21    The Call of the Wild  135000000   107300000
# 13  UNIVERSAL 2020-02-28       The Invisible Man    7000000   122700000
# 14     DISNEY 2020-03-06                  Onward  175000000   101700000
# 15     WARNER 2020-03-06            The Way Back   25000000    14100000
# 16  LIONSGATE 2020-03-13         I Still Believe    7000000     9500000
# 17       SONY 2020-03-13               Bloodshot   45000000    24400000
# 18  UNIVERSAL 2020-03-13                The Hunt   14000000     6000000
#
#     MULTIPLIER       TYPE
# 0         4.94  Franchise
# 1         0.60   Original
# 2         0.90   Original
# 3         4.64     Sequel
# 4         1.28     Reboot
# 5         1.32      Novel
# 6         0.12      Novel
# 7         2.34  Franchise
# 8         0.59   Original
# 9         3.52         IP
# 10        6.56         IP
# 11        1.29   Original
# 12        0.79      Novel
# 13       17.53      Novel
# 14        0.58   Original
# 15        0.56   Original
# 16        1.36     Biopic
# 17        0.54         IP
# 18        0.43   Original

# %% [markdown]
# If we want to filter the data, pandas provides the `loc` method. The basic functionality of loc is to select specific row or specific columns or specific cells. Go through this tutorial https://www.geeksforgeeks.org/python-pandas-dataframe-loc/# and mess around with selecting rows/columns for the `movie_df`.
#
# ### Exercise
# Lets practice in the below two cells what you learned from the tutorial linked above

# %%
# select the range of rows from 1 to 7
#movie_df.loc[] # fill in the []

# %%
# select just the MOVIE and BUDGET columns
#movie_df.loc[] # fill in the []

# %% [markdown]
# ### Filtering Data (continued)
#
# `loc` can also let you filter data according to a condition. Say for example you want to select data with a budget > $15,000,000 . You can specify the `loc` like so

# %%
movie_df.loc[movie_df["BUDGET"]>15000000]
# Out:
#        STUDIO       DATE                 MOVIE     BUDGET  BOX OFFICE
# 1         FOX 2020-01-10            Underwater   65000000    39200000  \
# 2   PARAMOUNT 2020-01-10           Like A Boss   29000000    26100000
# 3        SONY 2020-01-17     Bad Boys for Life   90000000   417600000
# 4   UNIVERSAL 2020-01-17              Dolittle  175000000   223300000
# 6   PARAMOUNT 2020-01-31    The Rhythm Section   50000000     5900000
# 7      WARNER 2020-02-07         Birds of Prey   84500000   197900000
# 9   PARAMOUNT 2020-02-14    Sonic the Hedgehog   85000000   299600000
# 11  UNIVERSAL 2020-02-14        The Photograph   16000000    20700000
# 12        FOX 2020-02-21  The Call of the Wild  135000000   107300000
# 14     DISNEY 2020-03-06                Onward  175000000   101700000
# 15     WARNER 2020-03-06          The Way Back   25000000    14100000
# 17       SONY 2020-03-13             Bloodshot   45000000    24400000
#
#     MULTIPLIER       TYPE
# 1         0.60   Original
# 2         0.90   Original
# 3         4.64     Sequel
# 4         1.28     Reboot
# 6         0.12      Novel
# 7         2.34  Franchise
# 9         3.52         IP
# 11        1.29   Original
# 12        0.79      Novel
# 14        0.58   Original
# 15        0.56   Original
# 17        0.54         IP

# %% [markdown]
# You can filter with multiple conditions using operators '&' and '|' . Enclose each condition with ()

# %%
# select movies with a budget of >15000000 AND the type is "Original"
movie_df.loc[(movie_df["BUDGET"]>15000000) & (movie_df["TYPE"]=="Original")]
# Out:
#        STUDIO       DATE           MOVIE     BUDGET  BOX OFFICE  MULTIPLIER
# 1         FOX 2020-01-10      Underwater   65000000    39200000        0.60  \
# 2   PARAMOUNT 2020-01-10     Like A Boss   29000000    26100000        0.90
# 11  UNIVERSAL 2020-02-14  The Photograph   16000000    20700000        1.29
# 14     DISNEY 2020-03-06          Onward  175000000   101700000        0.58
# 15     WARNER 2020-03-06    The Way Back   25000000    14100000        0.56
#
#         TYPE
# 1   Original
# 2   Original
# 11  Original
# 14  Original
# 15  Original

# %%
# select movies either with a budget of >15000000 OR the type is "Original"
movie_df.loc[(movie_df["BUDGET"]>15000000) | (movie_df["TYPE"]=="Original")]
# Out:
#        STUDIO       DATE                   MOVIE     BUDGET  BOX OFFICE
# 1         FOX 2020-01-10              Underwater   65000000    39200000  \
# 2   PARAMOUNT 2020-01-10             Like A Boss   29000000    26100000
# 3        SONY 2020-01-17       Bad Boys for Life   90000000   417600000
# 4   UNIVERSAL 2020-01-17                Dolittle  175000000   223300000
# 6   PARAMOUNT 2020-01-31      The Rhythm Section   50000000     5900000
# 7      WARNER 2020-02-07           Birds of Prey   84500000   197900000
# 8         FOX 2020-02-14  Downhill (Searchlight)   15000000     8800000
# 9   PARAMOUNT 2020-02-14      Sonic the Hedgehog   85000000   299600000
# 11  UNIVERSAL 2020-02-14          The Photograph   16000000    20700000
# 12        FOX 2020-02-21    The Call of the Wild  135000000   107300000
# 14     DISNEY 2020-03-06                  Onward  175000000   101700000
# 15     WARNER 2020-03-06            The Way Back   25000000    14100000
# 17       SONY 2020-03-13               Bloodshot   45000000    24400000
# 18  UNIVERSAL 2020-03-13                The Hunt   14000000     6000000
#
#     MULTIPLIER       TYPE
# 1         0.60   Original
# 2         0.90   Original
# 3         4.64     Sequel
# 4         1.28     Reboot
# 6         0.12      Novel
# 7         2.34  Franchise
# 8         0.59   Original
# 9         3.52         IP
# 11        1.29   Original
# 12        0.79      Novel
# 14        0.58   Original
# 15        0.56   Original
# 17        0.54         IP
# 18        0.43   Original

# %% [markdown]
# ### Exercise
# try filtering based on other conditions and get a feel for using the `loc` function. Use the below cell

# %%
# mess around with loc
#movies_df.loc[]

# %% [markdown]
# ### Plotting data with Pandas and matplotlib
# Pandas also provides a 'plot' method where you can specify the x and y axis from the columns in your dataframe, and specify the kind of plot you want.
#
# The documentation for Pandas plot is here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html

# %%
movie_df.plot(x='MOVIE', y='BUDGET', kind="bar")
# Out:
# <Axes: xlabel='MOVIE'>

# %% [markdown]
# Pandas plot uses the `matplotlib` python package underneath to generate these plots. Matplotlib is a very powerful package for plotting data with a ton more options and customization than what pandas plot() provides. For example, see below:

# %%
# impot the pyplot package from matplotlib as plt
from matplotlib import pyplot as plt

# create a new DataFrame that is sorted by the BUDGET column
df_sorted = movie_df.sort_values(by='BUDGET')
# format the y axis to use millions of dollars
plt.yticks([0, 50000000, 100000000, 150000000, 200000000], ['0', '50', '100', '150', '200']);
# add y label for millions of dollars
plt.ylabel('Millions of Dollars');
# add a title to the top of the graph
plt.title('2020 Movie Budgets');
# rotate x axis labels 90 degrees
plt.xticks(rotation=90);
# add color ranges for the y-axis values (here green is the smallest budget range, red is the largest budget range)
plt.axhspan(0, 50000000, color='green', alpha=0.2);
plt.axhspan(50000000, 100000000, color='yellow', alpha=0.2);
plt.axhspan(100000000, 150000000, color='orange', alpha=0.2);
plt.axhspan(150000000, 200000000, color='red', alpha=0.2);
# make max y value 200 million
plt.ylim(0, 200000000)
# plot the sorted DataFrame with matplotlib
plt.bar(df_sorted['MOVIE'], df_sorted['BUDGET'], alpha=1);

# %% [markdown]
# The fact that matplotlib is so customizable is useful in a lot of situations and its good to keep in your backpocket. But for the most part, we'll be using the Pandas plot() method in this project. And later we'll be using the Geopandas package which is very useful for generating visualizations with maps.
#
# Lets see if we can find a correlation between the budget of a movie and its gross profit. This time we will use pandas directly to create the matplotlib graph object. Then we will use that object to format the graph appropriately.

# %% [markdown]
# ## Practice with Real Data
#
# Now lets practice loading up our actual datasets and generating plots. Similar to how we used pd.read_excel to load an excel file, we can use pd.read_csv can be used to load a csv file

# %%
df = pd.read_csv("data/temperaturedata/CtyAvTemp62016.csv", delimiter=',', skiprows=0, low_memory=False)

df
# Out:
#       OBJECTID_1  STATEFP  COUNTYFP  GEOID                  NAME        Lat
# 0              1        2       185   2185           North Slope  69.449343  \
# 1              2        2       188   2188      Northwest Arctic  67.005066
# 2              3        2       290   2290         Yukon-Koyukuk  65.375727
# 3              4        2       180   2180                  Nome  64.783686
# 4              5        2        90   2090  Fairbanks North Star  64.676044
# ...          ...      ...       ...    ...                   ...        ...
# 3228        3229       60        40  60040         Swains Island -11.054436
# 3229        3230       60        10  60010               Eastern -14.268114
# 3230        3231       60        50  60050               Western -14.335468
# 3231        3232       60        20  60020                Manu'a -14.219801
# 3232        3233       60        30  60030           Rose Island -14.536530
#
#              Lon           Date_       TempK
# 0    -153.472830  6/20/2016 0:00  278.599976
# 1    -160.021086  6/20/2016 0:00  281.899994
# 2    -151.577850  6/20/2016 0:00  283.600006
# 3    -164.188912  6/20/2016 0:00  279.375000
# 4    -146.548159  6/20/2016 0:00  283.224976
# ...          ...             ...         ...
# 3228 -171.069014  6/20/2016 0:00  300.750000
# 3229 -170.625706  6/20/2016 0:00  300.024994
# 3230 -170.784233  6/20/2016 0:00  300.024994
# 3231 -169.507697  6/20/2016 0:00  299.899994
# 3232 -168.151292  6/20/2016 0:00  299.899994
#
# [3233 rows x 9 columns]

# %% [markdown]
# You'll notice the table isn't displayed fully. That's normal, Jupyter truncates what is visible to save screen space. Rest assured the full data is present.
#
# ### Exercise
# 1. Can you figure out how to add another column to show temperature in Farenheit?
# 2. Learning what you have learned about filtering data and plotting with pandas, can you create the same charts here that you created with google sheets?
# Use the below cell (or use as many cells as you'd like!). You can create more cells below by clicking on Insert->Insert Cell Below (or Insert Cell Above) which will insert a cell below or above the currently selected cell.

# %% [markdown]
# ### Merging dataframes
#
# Something useful you can do with pandas dataframes is that you can merge two of them together based on the columns. Say for example you have loaded the following two datasets as data frames

# %%
# specifying sheet_name since there are three sheets in the 2016_HHSemPOWERMapHistoricalDataset.xlsx file
df1 = pd.read_excel("data/2016_HHSemPOWERMapHistoricalDataset.xlsx", sheet_name="County") 
df1
# Out:
#       FIPS_Code  County_FIPS_Code         County  State_FIPS_Code State
# 0          1001                 1       Autauga                 1   AL   \
# 1          1003                 3       Baldwin                 1   AL
# 2          1005                 5       Barbour                 1   AL
# 3          1007                 7          Bibb                 1   AL
# 4          1009                 9        Blount                 1   AL
# ...         ...               ...            ...              ...   ...
# 3223      72151               151       Yabucoa                72   PR
# 3224      72153               153         Yauco                72   PR
# 3225      78010                10   Saint Croix                78   VI
# 3226      78020                20    Saint John                78   VI
# 3227      78030                30  Saint Thomas                78   VI
#
#       Jan_2016_Medicare_Benes  Jan_2016_Power_Dependent_Devices_DME
# 0                        9025                                   546  \
# 1                       42231                                  2025
# 2                        5266                                   242
# 3                        4616                                   211
# 4                        8631                                   594
# ...                       ...                                   ...
# 3223                     7560                                   274
# 3224                     7094                                   263
# 3225                     8538                                    72
# 3226                      740                                    11
# 3227                     8290                                    58
#
#       Feb_2016_Medicare_Benes  Feb_2016_Power_Dependent_Devices_DME
# 0                        9043                                   546  \
# 1                       42434                                  2037
# 2                        5267                                   238
# 3                        4623                                   211
# 4                        8631                                   589
# ...                       ...                                   ...
# 3223                     7582                                   274
# 3224                     7117                                   245
# 3225                     8558                                    69
# 3226                      745                                    11
# 3227                     8295                                    60
#
#       Mar_2016_Medicare_Benes  ...  Aug_2016_Medicare_Benes
# 0                        9045  ...                     9142  \
# 1                       42599  ...                    43236
# 2                        5281  ...                     5310
# 3                        4623  ...                     4621
# 4                        8655  ...                     8670
# ...                       ...  ...                      ...
# 3223                     7592  ...                     7612
# 3224                     7118  ...                     7184
# 3225                     8558  ...                     8611
# 3226                      748  ...                      757
# 3227                     8301  ...                     8343
#
#       Aug_2016_Power_Dependent_Devices_DME  Sep_2016_Medicare_Benes
# 0                                      529                     9206  \
# 1                                     2034                    43434
# 2                                      251                     5342
# 3                                      194                     4635
# 4                                      567                     8708
# ...                                    ...                      ...
# 3223                                   272                     7643
# 3224                                   243                     7218
# 3225                                    53                     8663
# 3226                                     0                      760
# 3227                                    43                     8405
#
#       Sep_2016_Power_Dependent_Devices_DME   Oct_2016_Medicare_Benes
# 0                                       546                     9236  \
# 1                                      2041                    43669
# 2                                       254                     5348
# 3                                       190                     4620
# 4                                       575                     8710
# ...                                     ...                      ...
# 3223                                    271                     7653
# 3224                                    229                     7244
# 3225                                     56                     8674
# 3226                                      0                      765
# 3227                                     42                     8416
#
#       Oct_2016_Power_Dependent_Devices_DME   Nov_2016_Medicare_Benes
# 0                                       577                     9257  \
# 1                                      2117                    43855
# 2                                       260                     5352
# 3                                       209                     4624
# 4                                       585                     8733
# ...                                     ...                      ...
# 3223                                    276                     7650
# 3224                                    232                     7251
# 3225                                     55                     8681
# 3226                                     11                      765
# 3227                                     43                     8428
#
#       Nov_2016_Power_Dependent_Devices_DME   Dec_2016_Medicare_Benes
# 0                                       589                     9275  \
# 1                                      2133                    44002
# 2                                       264                     5345
# 3                                       218                     4620
# 4                                       591                     8712
# ...                                     ...                      ...
# 3223                                    267                     7648
# 3224                                    236                     7251
# 3225                                     53                     8667
# 3226                                     11                      762
# 3227                                     45                     8448
#
#       Dec_2016_Power_Dependent_Devices_DME
# 0                                       595
# 1                                      2129
# 2                                       254
# 3                                       222
# 4                                       594
# ...                                     ...
# 3223                                    257
# 3224                                    232
# 3225                                     52
# 3226                                     11
# 3227                                     47
#
# [3228 rows x 29 columns]

# %%
df2 = pd.read_csv("data/temperaturedata/CtyAvTemp62016.csv", delimiter=',', skiprows=0, low_memory=False)
df2
# Out:
#       OBJECTID_1  STATEFP  COUNTYFP  GEOID                  NAME        Lat
# 0              1        2       185   2185           North Slope  69.449343  \
# 1              2        2       188   2188      Northwest Arctic  67.005066
# 2              3        2       290   2290         Yukon-Koyukuk  65.375727
# 3              4        2       180   2180                  Nome  64.783686
# 4              5        2        90   2090  Fairbanks North Star  64.676044
# ...          ...      ...       ...    ...                   ...        ...
# 3228        3229       60        40  60040         Swains Island -11.054436
# 3229        3230       60        10  60010               Eastern -14.268114
# 3230        3231       60        50  60050               Western -14.335468
# 3231        3232       60        20  60020                Manu'a -14.219801
# 3232        3233       60        30  60030           Rose Island -14.536530
#
#              Lon           Date_       TempK
# 0    -153.472830  6/20/2016 0:00  278.599976
# 1    -160.021086  6/20/2016 0:00  281.899994
# 2    -151.577850  6/20/2016 0:00  283.600006
# 3    -164.188912  6/20/2016 0:00  279.375000
# 4    -146.548159  6/20/2016 0:00  283.224976
# ...          ...             ...         ...
# 3228 -171.069014  6/20/2016 0:00  300.750000
# 3229 -170.625706  6/20/2016 0:00  300.024994
# 3230 -170.784233  6/20/2016 0:00  300.024994
# 3231 -169.507697  6/20/2016 0:00  299.899994
# 3232 -168.151292  6/20/2016 0:00  299.899994
#
# [3233 rows x 9 columns]

# %% [markdown]
# Something you'll notice is that FIPS_Code in df1 and GEOID in df2 are both FIPS Code values. Each df represents a county in each row. __NOTE:__ You'll also notice that they don't have the same number of rows, indicating not all counties may be represented in both dfs i.e. counties represented in one df may not be represented in the other. You'll encounter missing data like this in other places as well. That's something to be wary of: don't assume your data is perfect. We'll be working with the data we have in this project, so we won't worry about missing counties.
#
# Now we can merge both dataframes into one dataframe where the rows corresponding to the same FIPS code are smooshed together into the same row. We do this with the `merge` method (see documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html )

# %%
df_merged = df1.merge(df2, how="inner", left_on="FIPS_Code", right_on="GEOID")
df_merged
# Out:
#       FIPS_Code  County_FIPS_Code         County  State_FIPS_Code State
# 0          1001                 1       Autauga                 1   AL   \
# 1          1003                 3       Baldwin                 1   AL
# 2          1005                 5       Barbour                 1   AL
# 3          1007                 7          Bibb                 1   AL
# 4          1009                 9        Blount                 1   AL
# ...         ...               ...            ...              ...   ...
# 3221      72151               151       Yabucoa                72   PR
# 3222      72153               153         Yauco                72   PR
# 3223      78010                10   Saint Croix                78   VI
# 3224      78020                20    Saint John                78   VI
# 3225      78030                30  Saint Thomas                78   VI
#
#       Jan_2016_Medicare_Benes  Jan_2016_Power_Dependent_Devices_DME
# 0                        9025                                   546  \
# 1                       42231                                  2025
# 2                        5266                                   242
# 3                        4616                                   211
# 4                        8631                                   594
# ...                       ...                                   ...
# 3221                     7560                                   274
# 3222                     7094                                   263
# 3223                     8538                                    72
# 3224                      740                                    11
# 3225                     8290                                    58
#
#       Feb_2016_Medicare_Benes  Feb_2016_Power_Dependent_Devices_DME
# 0                        9043                                   546  \
# 1                       42434                                  2037
# 2                        5267                                   238
# 3                        4623                                   211
# 4                        8631                                   589
# ...                       ...                                   ...
# 3221                     7582                                   274
# 3222                     7117                                   245
# 3223                     8558                                    69
# 3224                      745                                    11
# 3225                     8295                                    60
#
#       Mar_2016_Medicare_Benes  ...  Dec_2016_Power_Dependent_Devices_DME
# 0                        9045  ...                                    595  \
# 1                       42599  ...                                   2129
# 2                        5281  ...                                    254
# 3                        4623  ...                                    222
# 4                        8655  ...                                    594
# ...                       ...  ...                                    ...
# 3221                     7592  ...                                    257
# 3222                     7118  ...                                    232
# 3223                     8558  ...                                     52
# 3224                      748  ...                                     11
# 3225                     8301  ...                                     47
#
#       OBJECTID_1  STATEFP  COUNTYFP  GEOID        NAME        Lat        Lon
# 0           2616        1         1   1001     Autauga  32.532237 -86.646439  \
# 1           2885        1         3   1003     Baldwin  30.659218 -87.746067
# 2           2899        1         5   1005     Barbour  31.870253 -85.405103
# 3           2627        1         7   1007        Bibb  33.015893 -87.127148
# 4           2613        1         9   1009      Blount  33.977357 -86.566440
# ...          ...      ...       ...    ...         ...        ...        ...
# 3221        3177       72       151  72151     Yabucoa  18.059858 -65.859871
# 3222        3151       72       153  72153       Yauco  18.085669 -66.857901
# 3223        3191       78        10  78010   St. Croix  17.735321 -64.746741
# 3224        3197       78        20  78020    St. John  18.330435 -64.735261
# 3225        3174       78        30  78030  St. Thomas  18.326748 -64.971251
#
#                Date_       TempK
# 0     6/20/2016 0:00  296.175018
# 1     6/20/2016 0:00  298.000000
# 2     6/20/2016 0:00  298.125000
# 3     6/20/2016 0:00  296.175018
# 4     6/20/2016 0:00  296.175018
# ...              ...         ...
# 3221  6/20/2016 0:00  301.200012
# 3222  6/20/2016 0:00  300.924988
# 3223  6/20/2016 0:00  301.200012
# 3224  6/20/2016 0:00  301.200012
# 3225  6/20/2016 0:00  301.200012
#
# [3226 rows x 38 columns]

# %% [markdown]
# In the above cell, the `merge()` method is called from one dataframe (considered the 'left' dataframe) and takes as arguments the other dataframe (called the 'right' dataframe), the method used to merge ('inner' means we use values that are present in the selected columns to merge on in both dataframes), and the left and right dataframe's columns to compare when merging ('left_on' is 'FIPS_Code' in the left dataframe and 'right_on' is 'GEOID' in the right dataframe, since they are both FIPS Code values).

# %% [markdown]
# ### Exercise
# 1. Try experimenting with other kinds of merge methods other than 'inner'. What do they do?
# 2. Can you create a chart that displays both temperature and Jun_2016_Power_Dependent_Devices_DME from your merged df? As an example see https://github.com/secondspass/jupyter_bootcampproject_examples/blob/master/intro_notebooks/intro.ipynb to see how to do multiple bars in a bar chart
#     a. This might result in a very large barchart, so how would you filter your dataframe down to specific counties? Then draw charts visualizing this information for specific counties you want.
